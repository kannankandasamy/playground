# %%
import cv2
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
im = cv2.imread('C:\\Users\\kanna\\Downloads\\img1.jpeg')[:,:,::-1]

# %%
plt.imshow(im)

# %%
#im[0][0]

#type(im)

im.shape
# Out:
# (228, 221, 3)

# %%
plt.imshow(im[72:144, 72:144, :])

# %%
plt.imshow(im[72:75, 72:75, :])

# %%
im_grey = np.mean(im, axis=2)

# %%
print(im_grey.shape)
print(im_grey.dtype)

plt.imshow(im_grey, cmap='gray')
# Out:
# (228, 221)
# float64

# %%
im1 = im/255

# %%
f, arr = plt.subplots(1,3)
arr[0].imshow(im1)
arr[1].imshow(im1+0.2)
arr[2].imshow(im1-0.2)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
f, arr = plt.subplots(1,3)
arr[0].imshow(im1)
arr[1].imshow(im1*0.2)
arr[2].imshow(im1*(1.2))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
f, arr = plt.subplots(1,3)
arr[0].imshow(im1)
arr[1].imshow(im1*0.2)
arr[2].imshow(1-im1)
